# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats
import seaborn as sns

# %%
df = pd.read_csv("water_potability.csv")

# %% [markdown]
# df.head()

# %% [markdown]
# <h1>Step 1</h1>

# %%
df_sub = df.drop(columns=['Hardness', 'ph', 'Solids', 'Chloramines', 'Potability', 'Turbidity', 'Conductivity'])

# %%
df_sub.head()
# Out:
#       Sulfate  Organic_carbon  Trihalomethanes
# 0  368.516441       10.379783        86.990970
# 1         NaN       15.180013        56.329076
# 2         NaN       16.868637        66.420093
# 3  356.886136       18.436524       100.341674
# 4  310.135738       11.558279        31.997993

# %%
df_sub = df_sub.dropna()

# %%
sulfate = df_sub.Sulfate
organic_carbon = df_sub.Organic_carbon
trihalomethanes = df_sub.Trihalomethanes

# %% [markdown]
# <h1>Step 2</h1>

# %%
plt.figure(figsize=(10, 6))
sns.histplot(sulfate, kde=True)
plt.savefig("Sulfate_kde.png", format='PNG')

# %%
plt.figure(figsize=(10, 6))
sns.histplot(organic_carbon, kde=True)
plt.savefig("Organic_carbon_kde.png", format='PNG')

# %%
plt.figure(figsize=(10, 6))
sns.histplot(trihalomethanes, kde=True)
plt.savefig("Trihalomethanes_kde.png", format='PNG')

# %% [markdown]
# <h1>Step 3</h1>

# %%
df_sub.describe()
# Out:
#            Sulfate  Organic_carbon  Trihalomethanes
# count  2373.000000     2373.000000      2373.000000
# mean    333.642005       14.332704        66.293795
# std      41.421249        3.315060        16.079466
# min     129.000000        2.200000         8.577013
# 25%     307.563455       12.085026        55.701067
# 50%     332.890382       14.261743        66.542198
# 75%     359.948574       16.642480        77.152173
# max     481.030642       27.006707       124.000000

# %%
sns.boxplot(data=sulfate, showfliers=False, orient='h',\
            boxprops = {'facecolor':'none'})
plt.title("sulfate")
plt.savefig("Sulfate_boxplot.png", format='PNG')

# %%
sns.boxplot(data=organic_carbon, showfliers=False, orient='h',\
            boxprops = {'facecolor':'none'})
plt.title("organic_carbon")
plt.savefig("Organic_carbon_boxplot.png", format='PNG')

# %%
sns.boxplot(data=trihalomethanes, showfliers=False, orient='h',\
            boxprops = {'facecolor':'none'})
plt.title("trihalomethanes")
plt.savefig("Trihalomethanes_boxplot.png", format='PNG')

# %% [markdown]
# <h1>Step 4</h1>

# %%
from scipy.stats import norm

# %% [markdown]
# <h1>Step 5 and Step 7</h1>

# %%
def norm_params_ls(data, bins=20):
    min_val, max_val = data.min(), data.max()
    hist, _ = np.histogram(data, bins=bins, density=True)
    xs = np.linspace(min_val, max_val, num=bins)
    
    p, _ = scipy.optimize.curve_fit(scipy.stats.norm.pdf, xs, dists, maxfev=1000)
    
    return p

# %%
params_sulfate = norm.fit(sulfate, method="MM")
params_organic_carbon = norm.fit(organic_carbon, method="MM")
params_trihalomethanes = norm.fit(trihalomethanes, method="MM")

ls_params_sulfate = estimate_params_ls(sulfate)
ls_params_organic_carbon = estimate_params_ls(organic_carbon)
ls_params_trihalomethanes = estimate_params_ls(trihalomethanes)

# %%
plt.figure(figsize=(10, 8))
plt.title("sulfate")
sns.histplot(sulfate, kde=False, stat='density')
x = np.linspace(np.min(sulfate), np.max(sulfate))
pdf = scipy.stats.norm.pdf(x, *params_sulfate) 
pdf2 = scipy.stats.norm.pdf(x, *ls_params_sulfate)
plt.plot(x, pdf, 'r--',\
         label=f"Moments method:\
         loc = {round(params_sulfate[0], 2)},\
         scale = {round(params_sulfate[1], 2)}".format())
plt.plot(x, pdf2, 'y--',\
         label=f"Least squares method:\
         loc = {round(ls_params_sulfate[0], 2)},\
         scale = {round(ls_params_sulfate[1], 2)}".format())
plt.legend()
plt.savefig("Sulfate_MM.png", format='PNG')

# %%
print("MM: ", scipy.stats.kstest(sulfate, 'norm', params_sulfate))
print("LS: ", scipy.stats.kstest(sulfate, 'norm', ls_params_sulfate))
print("MM: ", scipy.stats.cramervonmises(sulfate, 'norm', params_sulfate))
print("LS: ", scipy.stats.cramervonmises(sulfate, 'norm', ls_params_sulfate))
# Out:
# MM:  KstestResult(statistic=0.02243557387100803, pvalue=0.18059222146409026)
# LS:  KstestResult(statistic=0.0219219260381186, pvalue=0.20122981897155334)
# MM:  CramerVonMisesResult(statistic=0.34436643623158686, pvalue=0.10185423161578688)
# LS:  CramerVonMisesResult(statistic=0.2028799767719379, pvalue=0.26196940183959794)

# %%
plt.figure(figsize=(10, 8))
plt.title("organic_carbon")
sns.histplot(organic_carbon, kde=False, stat='density')
x = np.linspace(np.min(organic_carbon), np.max(organic_carbon))
pdf = scipy.stats.norm.pdf(x, *params_organic_carbon) 
pdf2 = scipy.stats.norm.pdf(x, *ls_params_organic_carbon) 
plt.plot(x, pdf, 'r--',\
         label=f"Moments method:\
         loc = {round(params_organic_carbon[0], 2)},\
         scale = {round(params_organic_carbon[1], 2)}".format())
plt.plot(x, pdf2, 'y--',\
         label=f"Least squares method:\
         loc = {round(ls_params_organic_carbon[0], 2)},\
         scale = {round(ls_params_organic_carbon[1], 2)}".format())
plt.legend()
plt.savefig("Organic_carbon_MM.png")

# %%
print("MM: ", scipy.stats.kstest(organic_carbon, 'norm', params_organic_carbon))
print("LS: ", scipy.stats.kstest(organic_carbon, 'norm', ls_params_organic_carbon))
print("MM: ", scipy.stats.cramervonmises(organic_carbon, 'norm', params_organic_carbon))
print("LS: ", scipy.stats.cramervonmises(organic_carbon, 'norm', ls_params_organic_carbon))
# Out:
# MM:  KstestResult(statistic=0.01249179778754994, pvalue=0.848148952232119)
# LS:  KstestResult(statistic=0.017552049625360805, pvalue=0.45261666625128805)
# MM:  CramerVonMisesResult(statistic=0.047282171023285816, pvalue=0.8926161341464085)
# LS:  CramerVonMisesResult(statistic=0.12713681549241543, pvalue=0.46744360284332254)

# %%
plt.figure(figsize=(10, 8))
plt.title("trihalomethanes")
sns.histplot(trihalomethanes, kde=False, stat='density')
x = np.linspace(np.min(trihalomethanes), np.max(trihalomethanes))
pdf = scipy.stats.norm.pdf(x, *params_trihalomethanes) 
pdf2 = scipy.stats.norm.pdf(x, *ls_params_trihalomethanes) 
plt.plot(x, pdf, 'r--',\
         label=f"Moments method:\
         loc = {round(params_trihalomethanes[0], 2)},\
         scale = {round(params_trihalomethanes[1], 2)}".format())
plt.plot(x, pdf2, 'y--',\
         label=f"Least squares method:\
         loc = {round(ls_params_trihalomethanes[0], 2)},\
         scale = {round(ls_params_trihalomethanes[1], 2)}".format())
plt.legend()
plt.savefig("Trihalomethanes_MM.png")

# %%
print("MM: ", scipy.stats.kstest(trihalomethanes, 'norm', params_trihalomethanes))
print("LS: ", scipy.stats.kstest(trihalomethanes, 'norm', ls_params_trihalomethanes))
print("MM: ", scipy.stats.cramervonmises(trihalomethanes, 'norm', params_trihalomethanes))
print("LS: ", scipy.stats.cramervonmises(trihalomethanes, 'norm', ls_params_trihalomethanes))
# Out:
# MM:  KstestResult(statistic=0.023414980226688142, pvalue=0.1458796275142239)
# LS:  KstestResult(statistic=0.01566472606641056, pvalue=0.5995161907026348)
# MM:  CramerVonMisesResult(statistic=0.11933287466782826, pvalue=0.4981746292786823)
# LS:  CramerVonMisesResult(statistic=0.15262736552197012, pvalue=0.38168901261188704)

# %% [markdown]
# <h1>Step 6</h1>

# %%
# Calculation of quantiles
percs = np.linspace(5, 95, 19)
qn_first = np.percentile(sulfate, percs)
qn_norm = scipy.stats.norm.ppf(percs / 100.0, *params_sulfate)


min_qn = np.min([qn_first.min(), qn_norm.min()])
max_qn = np.max([qn_first.max(), qn_norm.max()])
x = np.linspace(min_qn - 50, max_qn + 50)

# Building a quantile biplot
plt.figure(figsize=(10, 8))
plt.plot(qn_first, qn_norm, ls="", marker="o", markersize=8)
plt.plot(x, x, color="k", ls="--")
plt.xlabel('Empirical distribution')
plt.ylabel('Theoretical distribution')

plt.title('QQ-plot Sulfate')
plt.savefig("Sulfate_QQ.png")

# %%
# Calculation of quantiles
percs = np.linspace(5, 95, 19)
qn_first = np.percentile(organic_carbon, percs)
qn_norm = scipy.stats.norm.ppf(percs / 100.0, *params_organic_carbon)

min_qn = np.min([qn_first.min(), qn_norm.min()])
max_qn = np.max([qn_first.max(), qn_norm.max()])
x = np.linspace(min_qn - 3, max_qn + 3)

# Building a quantile biplot
plt.figure(figsize=(10, 8))
plt.plot(qn_first, qn_norm, ls="", marker="o", markersize=8)
plt.plot(x, x, color="k", ls="--")
plt.xlabel('Empirical distribution')
plt.ylabel('Theoretical distribution')

plt.title('QQ-plot Organic carbon')
plt.savefig("Organic_carbon_QQ.png")

# %%
# Calculation of quantiles
percs = np.linspace(5, 95, 19)
qn_first = np.percentile(trihalomethanes, percs)
qn_norm = scipy.stats.norm.ppf(percs / 100.0, *params_trihalomethanes)

min_qn = np.min([qn_first.min(), qn_norm.min()])
max_qn = np.max([qn_first.max(), qn_norm.max()])
x = np.linspace(min_qn - 10, max_qn + 10)

# Building a quantile biplot
plt.figure(figsize=(10, 8))
plt.plot(qn_first, qn_norm, ls="", marker="o", markersize=8)
plt.plot(x, x, color="k", ls="--")
plt.xlabel('Empirical distribution')
plt.ylabel('Theoretical distribution')

plt.title('QQ-plot Trihalomethanes')
plt.savefig("Trihalomethanes_QQ.png")
